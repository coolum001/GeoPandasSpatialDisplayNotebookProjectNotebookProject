# %%
# %matplotlib inline
import geopandas as gpd
guayapol = gpd.read_file('shp/Guayaqui_Poligonos.shp')

# %%
guayapol.columns
# Out:
# Index(['osm_id', 'osm_way_id', 'name', 'type', 'aeroway', 'amenity',
#        'admin_leve', 'barrier', 'boundary', 'building', 'craft', 'geological',
#        'historic', 'land_area', 'landuse', 'leisure', 'man_made', 'military',
#        'natural', 'office', 'place', 'shop', 'sport', 'tourism', 'other_tags',
#        'Area', 'geometry'],
#       dtype='object')

# %%
guayapol.head()
# Out:
#     osm_id osm_way_id                      name          type aeroway amenity  \
# 0  2048284                          Los Ãlamos      boundary
# 1  6415358             Centro Comercial Polaris  multipolygon
# 2            35692043          Parque de la 4ta
# 3            35692054              Albocentro I
# 4            35692055             Albocentro II
#
#   admin_leve barrier        boundary    building  \
# 0         10          administrative
# 1                                     commercial
# 2
# 3                                         retail
# 4                                         retail
#
#                          ...                         military natural office  \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   place shop sport tourism                                         other_tags  \
# 0                           "is_in:county"=>"Guayaquil","wikidata"=>"Q5547...
# 1                                         "addr:street"=>"Isidro Ayora Cueva"
# 2
# 3
# 4
#
#          Area                                           geometry
# 0  411645.776  POLYGON ((-79.90770759999999 -2.133868, -79.90...
# 1    3600.819  (POLYGON ((-79.90053709999999 -2.1177451, -79....
# 2    3827.957  POLYGON ((-79.8947605 -2.1381131, -79.8945496 ...
# 3    1010.729  POLYGON ((-79.8967722 -2.1408807, -79.8966862 ...
# 4    1470.616  POLYGON ((-79.8978609 -2.140057, -79.8976332 -...
#
# [5 rows x 27 columns]

# %%
guayapol.plot()

# %%
for item in guayapol.columns[:-1]:
    uniquelist = guayapol[item].unique()
    if uniquelist.flatten().shape[0] < 10:
        print('Column name: {}'.format(item))
        print('Unique values: {}'.format(guayapol[item].unique()))
        print('----------')
# Out:
# Column name: osm_id
# Unique values: ['2048284' '6415358' '']
# ----------
# Column name: type
# Unique values: ['boundary' 'multipolygon' '']
# ----------
# Column name: aeroway
# Unique values: ['']
# ----------
# Column name: admin_leve
# Unique values: ['10' '' '9']
# ----------
# Column name: barrier
# Unique values: ['']
# ----------
# Column name: boundary
# Unique values: ['administrative' '']
# ----------
# Column name: craft
# Unique values: ['' 'electronics_repair' 'upholsterer']
# ----------
# Column name: geological
# Unique values: ['']
# ----------
# Column name: historic
# Unique values: ['']
# ----------
# Column name: land_area
# Unique values: ['']
# ----------
# Column name: landuse
# Unique values: ['' 'retail' 'industrial' 'residential' 'commercial' 'recreation_ground']
# ----------
# Column name: leisure
# Unique values: ['' 'park' 'pitch' 'recreation_ground' 'playground' 'sports_centre'
#  'dancing' 'swimming_pool']
# ----------
# Column name: man_made
# Unique values: ['']
# ----------
# Column name: military
# Unique values: ['']
# ----------
# Column name: natural
# Unique values: ['' 'water']
# ----------
# Column name: office
# Unique values: ['' 'educational_institution' 'newspaper' 'medical' 'telecommunication'
#  'company' 'yes' 'government']
# ----------
# Column name: place
# Unique values: ['']
# ----------
# Column name: sport
# Unique values: ['' 'multi' 'basketball' 'soccer' 'tennis']
# ----------
# Column name: tourism
# Unique values: ['' 'hotel' 'hostel']
# ----------

# %%
guayalanduse = guayapol[guayapol['landuse']!='']
guayalanduse.describe()
# Out:
#                 Area
# count      20.000000
# mean    93604.024600
# std    155448.646236
# min       524.921000
# 25%      3229.351500
# 50%     15509.771000
# 75%    105302.365750
# max    584652.933000

# %%
guayalanduse.plot()

# %%
import matplotlib.pyplot as plt
guayalanduse.plot(column='landuse')

# %%
guayalanduse.total_bounds
# Out:
# array([-79.9175919,  -2.1412161, -79.8821258,  -2.1161658])

# %%
guayapark = guayapol[guayapol['leisure']=='park']
guayapark.plot()

# %%
guayapark.describe()
# Out:
#                Area
# count     69.000000
# mean    1791.947362
# std     1958.444054
# min      120.123000
# 25%      598.119000
# 50%     1103.094000
# 75%     2039.530000
# max    10042.033000
